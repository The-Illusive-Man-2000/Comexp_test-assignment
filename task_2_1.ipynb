# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from torch.autograd import Variable
from torchvision import datasets
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as data_utils
import torch
from torch.utils.data import TensorDataset, DataLoader

from sklearn.model_selection import train_test_split
import gzip

# %%
# Фиксируем seed для воспроизводимости результатов
torch.manual_seed(42) #  для cpu
#torch.cuda.manual_seed(42)    # для gpu
np.random.seed(42) #  для numpy

# %%
f = gzip.open('train-images-idx3-ubyte-32x32.gz','r')

image_size = 32
num_images = 60000

# Первые 8 байтов не содержат данные датасета поэтому сначала считываем их, потом всё остальное
f.read(8)

# Считываем данные из файла. Потом решейпим их.
buf = f.read(image_size * image_size * num_images)
data = np.frombuffer(buf, dtype=np.uint8).astype(np.float32)
data = data.reshape(num_images, image_size, image_size, 1)

# %%
# Выведем и отриуем один объект из набора данных чтобы просто посмотреть.
image = np.asarray(data[19]).squeeze()

fig, ax = plt.subplots()
ax.imshow(image)
plt.show()

# %%
# Откроем файл с метками. Выведем первые 20 меток, чтобы просто посмотреть. Да, с индексом 19 у нас девятка.
f = gzip.open('train-labels-idx1-ubyte.gz','r')
f.read(8)
buf = f.read()
labels = np.frombuffer(buf, dtype=np.uint8).astype(np.int64)
print(labels[:20])
# Out:
# [5 0 4 1 9 2 1 3 1 4 3 5 3 6 1 7 2 8 6 9]

# %%
# Посмотрим сбалансированы ли классы.
plt.hist(labels)
plt.show()

# %%
# Классы сбалансированы.Количество картинок каждой цифры примерно одинаковое.

# %%
data = data.reshape(num_images, 1, image_size, image_size)
print(data.shape)

# Отщипнем 10 примеров чтобы вывести эти изображения и результат обученной модели по каждому из них в самом конце.
data_train = data[0:59990]
test = data[59990:]

labels = labels[0:59990]
# Out:
# (60000, 1, 32, 32)

# %%
# Разделим наши данные на часть для обучения и на часть для проверки, как наша модель обучилась. 
train0, val0, train_labels0, val_labels0 = train_test_split(data_train, labels,
                                                                    train_size=0.9, shuffle=True)
# Делаем торчевские тензоры из наших данных
train0 = torch.FloatTensor(train0) 
train_labels0 = torch.LongTensor(train_labels0) 
val0 = torch.FloatTensor(val0) 
val_labels0 = torch.LongTensor(val_labels0) 

# Собираем признаки и метки в один тензор
train = TensorDataset(train0, train_labels0)
val = TensorDataset(val0, val_labels0)

batch_size = 32
train_loader = torch.utils.data.DataLoader(train, batch_size = batch_size, drop_last=True)
val_loader = torch.utils.data.DataLoader(val, batch_size = batch_size, drop_last=True)

# %%
# Выбираем девайс на котром будет происходить обучение
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
# Создаём класс для нейросети. Архитектура сети Lenet.

class LeNet(nn.Module):
    def __init__(self):
        super(LeNet, self).__init__()
        
        self.conv1 = nn.Conv2d(1, 6, 3)
        self.relu1 = nn.ReLU()
        self.pool1 = nn.MaxPool2d((2, 2))  
        self.conv2 = nn.Conv2d(6, 16, 3)  
        self.relu2 = nn.ReLU()                          
        self.pool2 = nn.MaxPool2d((2, 2))  
        self.flatten = nn.Flatten()                         
        
        self.fc1 = nn.Linear(16*6*6, 120)  
        self.relu3 = nn.ReLU()                          
        self.fc2 = nn.Linear(120, 84) 
        self.relu4 = nn.ReLU()                          
        self.fc3 = nn.Linear(84, 10) 

    def forward(self, x):
        x =  self.conv1(x)
        x =  self.relu1(x)       
        x = self.pool1(x)
        x = self.conv2(x)                          
        x = self.relu2(x)
        x = self.pool2(x)
        x = self.flatten(x)
        
        x = self.fc1(x)
        x = self.relu3(x)
        x = self.fc2(x)                          
        x = self.relu4(x)                          
        x = self.fc3(x)                          
        
        return x

# %%
# модель - экземпляр класса
model = LeNet().to(device)

# Лосс функция. Она будет задавать поверхность ошибок по которой мы будем двигаться и искать минимум с помощью градиентного спуска. 
criterion = nn.CrossEntropyLoss()

# Оптимизатор. Отвечает за то, как будут обновляться веса нашей модели. Разные оптимизаторы- разные формулы обновления весов.
# Обычно из коробки хорошо работает адам - адаптивный момент.
optimizer = torch.optim.Adam(model.parameters())

loaders = {"train": train_loader, "valid": val_loader}

print(model)
# Out:
# LeNet(
#   (conv1): Conv2d(1, 6, kernel_size=(3, 3), stride=(1, 1))
#   (relu1): ReLU()
#   (pool1): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(6, 16, kernel_size=(3, 3), stride=(1, 1))
#   (relu2): ReLU()
#   (pool2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (fc1): Linear(in_features=576, out_features=120, bias=True)
#   (relu3): ReLU()
#   (fc2): Linear(in_features=120, out_features=84, bias=True)
#   (relu4): ReLU()
#   (fc3): Linear(in_features=84, out_features=10, bias=True)
# )

# %%
# Обучим нашу модель на 10 эпохах.
# Вообще Accuracy такая себе метрика. Но у нас классы более-менее сбалансированы, поэтому можно применить Accuracy.
max_epochs = 10
accuracy = {"train": [], "valid": []}
for epoch in range(max_epochs):
    for k, dataloader in loaders.items():
        epoch_correct = 0
        epoch_all = 0
        for x_batch, y_batch in dataloader:
            if k == "train":
                
                model.train()
                optimizer.zero_grad()
                outp = model(x_batch)
          
    
            else:
                model.eval()
                with torch.no_grad():
                    outp = model(x_batch)
                
            preds = outp.argmax(-1)
            correct = preds.eq(y_batch.data.view_as(preds)).bool().int().sum() 
            all = batch_size  
            epoch_correct += correct.item()
            epoch_all += all
            if k == "train":
                loss = criterion(outp, y_batch)
                loss.backward()
                optimizer.step()
                
        if k == "train":
            print(f"Epoch: {epoch+1}")
        print(f"Loader: {k}. Accuracy: {epoch_correct/epoch_all}")
        accuracy[k].append(epoch_correct/epoch_all)
# Out:
# Epoch: 1
# Loader: train. Accuracy: 0.9447799347954949
# Loader: valid. Accuracy: 0.9772727272727273
# Epoch: 2
# Loader: train. Accuracy: 0.9755853586247777
# Loader: valid. Accuracy: 0.9759358288770054
# Epoch: 3
# Loader: train. Accuracy: 0.9815130409010077
# Loader: valid. Accuracy: 0.9772727272727273
# Epoch: 4
# Loader: train. Accuracy: 0.9843657379964433
# Loader: valid. Accuracy: 0.9714237967914439
# Epoch: 5
# Loader: train. Accuracy: 0.9864404267931239
# Loader: valid. Accuracy: 0.9787767379679144
# Epoch: 6
# Loader: train. Accuracy: 0.9880705394190872
# Loader: valid. Accuracy: 0.9776069518716578
# Epoch: 7
# Loader: train. Accuracy: 0.9897006520450504
# Loader: valid. Accuracy: 0.9745989304812834
# Epoch: 8
# Loader: train. Accuracy: 0.990256372258447
# Loader: valid. Accuracy: 0.9787767379679144
# Epoch: 9
# Loader: train. Accuracy: 0.9917938648488441
# Loader: valid. Accuracy: 0.9766042780748663
# Epoch: 10
# Loader: train. Accuracy: 0.9917753408417309
# Loader: valid. Accuracy: 0.9742647058823529

# %%
# Метрика Accuracy на проверочной части данных 0.97

# %%
lenet_accuracy_val = accuracy["valid"]
lenet_accuracy_train = accuracy["train"]

# %%
# Выведем графики лосса на тренировочной и проверочной части нашего датасета.
plt.figure(figsize=(16, 10))
plt.title("Train and Valid accuracy")
plt.plot(range(max_epochs), lenet_accuracy_val, label="LeNet Val Accuracy", linewidth=2)
plt.plot(range(max_epochs), lenet_accuracy_train, label="LeNet Train Accuracy", linewidth=2)
plt.legend()
plt.xlabel("Epoch")
plt.show()

# %%
# Теперь посмотрим, как работает обученная модель. Мы зарезервировали ранее 10 примеров, которые не участвовали в обучении.
# Выведем цифру и мнение модели.


test = test.reshape(10,1, 32, 32)
test = torch.FloatTensor(test)

test_list = list(test)
out = model(test)
out_list = list(out)
#print(out.argmax())


for i in range (0,len(test_list)):
    fig, ax = plt.subplots()
    ax.imshow(test_list[i].reshape(32,32))
    plt.show()
    print("Цифра ", int(out_list[i].argmax()))
    print()
# Out:
# Цифра  9
# Цифра  2
# Цифра  9
# Цифра  5
# Цифра  1
# Цифра  8
# Цифра  3
# Цифра  5
# Цифра  6
# Цифра  8

# %%
# Модель правильно распознала все 10 примеров не участвовавших в её обучении.
